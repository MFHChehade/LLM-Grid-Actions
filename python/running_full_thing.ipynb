# %%
# %run psps_llm_pipeline
# Out:
# Case=case118: buses=118, lines=186
# N_RUNS=3, MASTER_SEED=123
#
# ...
# === RUN 0 ===
# ...
# [RUN 0] Building SFT raw corpus with seed=123
# [run_ground_truth FAIL] rc=1 out_exists=False xi=C:\Users\moham\Downloads\wildfire codes\io\psps_r0_00000.json mode=mip_opt
# [run_ground_truth FAIL] rc=1 out_exists=False xi=C:\Users\moham\Downloads\wildfire codes\io\psps_r0_00001.json mode=mip_opt
# [run_ground_truth FAIL] rc=1 out_exists=False xi=C:\Users\moham\Downloads\wildfire codes\io\psps_r0_00002.json mode=mip_opt
# [run_ground_truth FAIL] rc=1 out_exists=False xi=C:\Users\moham\Downloads\wildfire codes\io\psps_r0_00003.json mode=mip_opt
# [run_ground_truth FAIL] rc=1 out_exists=False xi=C:\Users\moham\Downloads\wildfire codes\io\psps_r0_00004.json mode=mip_opt
# [run_ground_truth FAIL] rc=1 out_exists=False xi=C:\Users\moham\Downloads\wildfire codes\io\psps_r0_00005.json mode=mip_opt
# ...
